# %%
import pandas as pd

# %%
# datasetpath
my_path = "../datasets/deliveries.csv"

# %% [markdown]
# # **Export to CSV**

# %%
df = pd.DataFrame()
# df.to
# this to is used to export to muliple format

# %%
df = pd.read_csv(my_path)
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# now suppose we need a new dataset which contains a batsman name and his total runs

# df.groupby('batsman')['total_runs'].sum()


# for name and runs
temp_df = (
    df.groupby("batsman")["total_runs"].sum().sort_values(ascending=False).reset_index()
)
temp_df
# Out:
#           batsman  total_runs
# 0        SK Raina        4745
# 1         V Kohli        4588
# 2       G Gambhir        4388
# 3       RG Sharma        4334
# 4       DA Warner        4213
# ..            ...         ...
# 456      L Ablish           0
# 457    RR Bhatkal           0
# 458     S Kaushik           0
# 459     IC Pandey           0
# 460  Abdur Razzak           0
#
# [461 rows x 2 columns]

# %%
# export this to csv
# Index false because we dont need extra column in csv because when we load it again we automatically gets the index by pandas

temp_df.to_csv("../datasets/my_custom_batsman_runs.csv", index=False)

# %%
# batsman vs team total runs

temp_df = df.pivot_table(
    index="batsman", columns="bowling_team", values="batsman_runs", aggfunc="sum"
)
temp_df
# Out:
# bowling_team    Chennai Super Kings  Deccan Chargers  Delhi Daredevils  \
# batsman
# A Ashish Reddy                 45.0              NaN              36.0
# A Chandila                      NaN              0.0               NaN
# A Chopra                        NaN             35.0              13.0
# A Choudhary                     NaN              NaN               NaN
# A Flintoff                      NaN              NaN              16.0
# ...                             ...              ...               ...
# YV Takawale                    19.0              5.0              14.0
# Yashpal Singh                   NaN              NaN              13.0
# Younis Khan                     NaN              NaN               NaN
# Yuvraj Singh                  321.0            118.0             433.0
# Z Khan                         39.0              4.0               4.0
#
# bowling_team    Gujarat Lions  Kings XI Punjab  Kochi Tuskers Kerala  \
# batsman
# ...

# %%
temp_df.to_csv("../datasets/batsman_vs_teams.csv")

# %% [markdown]
# # **Export to Excel**

# %%
df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
# Same Example

temp_df = (
    df.groupby("batsman")["total_runs"].sum().sort_values(ascending=False).reset_index()
)
temp_df
# Out:
#           batsman  total_runs
# 0        SK Raina        4745
# 1         V Kohli        4588
# 2       G Gambhir        4388
# 3       RG Sharma        4334
# 4       DA Warner        4213
# ..            ...         ...
# 456      L Ablish           0
# 457    RR Bhatkal           0
# 458     S Kaushik           0
# 459     IC Pandey           0
# 460  Abdur Razzak           0
#
# [461 rows x 2 columns]

# %%
temp_df.to_excel("../datasets/batsman_runs.xlsx")

# %%
# Store to custom sheets, or name a sheet

temp_df.to_excel("../datasets/batsman_runs.xlsx", sheet_name="batsman_run")

# %%
temp_df2 = df.pivot_table(
    index="batsman", columns="bowling_team", values="batsman_runs", aggfunc="sum"
)
temp_df2
# Out:
# bowling_team    Chennai Super Kings  Deccan Chargers  Delhi Daredevils  \
# batsman
# A Ashish Reddy                 45.0              NaN              36.0
# A Chandila                      NaN              0.0               NaN
# A Chopra                        NaN             35.0              13.0
# A Choudhary                     NaN              NaN               NaN
# A Flintoff                      NaN              NaN              16.0
# ...                             ...              ...               ...
# YV Takawale                    19.0              5.0              14.0
# Yashpal Singh                   NaN              NaN              13.0
# Younis Khan                     NaN              NaN               NaN
# Yuvraj Singh                  321.0            118.0             433.0
# Z Khan                         39.0              4.0               4.0
#
# bowling_team    Gujarat Lions  Kings XI Punjab  Kochi Tuskers Kerala  \
# batsman
# ...

# %%
# Storing multiple files in different sheets for excel
# with below sytanx file will be open, write and then save and close automatically


with pd.ExcelWriter("../datasets/outputs.xlsx") as writer:
    temp_df.to_excel(writer, sheet_name="batsman_run")
    temp_df2.to_excel(writer, sheet_name="batsman_vs_teams")

# %% [markdown]
# # **Export to HTML**
#
# - we can convert our analysis as html table
# - usefull when we need to convert our analysis as a blog to write somewhere

# %%
# har over ki konsi ball pe kitne runs pade hai aaj tak

temp_df = df.pivot_table(
    index="over", columns="ball", values="batsman_runs", aggfunc="sum"
)
temp_df
# Out:
# ball       1       2       3       4       5       6      7     8     9
# over
# 1      803.0   999.0  1056.0  1282.0  1191.0  1243.0  335.0  50.0   6.0
# 2     1162.0  1222.0  1270.0  1371.0  1399.0  1407.0  351.0  70.0  11.0
# 3     1403.0  1506.0  1485.0  1534.0  1452.0  1504.0  266.0  61.0  12.0
# 4     1414.0  1603.0  1559.0  1603.0  1537.0  1588.0  293.0  42.0   6.0
# 5     1474.0  1555.0  1675.0  1642.0  1594.0  1450.0  296.0  44.0   2.0
# 6     1509.0  1659.0  1514.0  1686.0  1528.0  1577.0  300.0  32.0  10.0
# 7     1182.0  1281.0  1216.0  1282.0  1415.0  1208.0  230.0  41.0   5.0
# 8     1391.0  1306.0  1468.0  1358.0  1431.0  1333.0  186.0  26.0   2.0
# 9     1506.0  1445.0  1407.0  1436.0  1394.0  1325.0  240.0  27.0   8.0
# 10    1341.0  1349.0  1458.0  1378.0  1411.0  1428.0  224.0  21.0   0.0
# 11    1446.0  1573.0  1493.0  1407.0  1492.0  1466.0  184.0  14.0   2.0
# 12    1511.0  1535.0  1541.0  1528.0  1499.0  1461.0  204.0  18.0   2.0
# ...

# %%
# har over ki konsi ball pe kitne 6 pade hai aaj tak
# run pivot table on values where batsmann run == 6
# either we can filter or directly apply query


temp_df = df.query("batsman_runs == 6").pivot_table(
    index="over", columns="ball", values="batsman_runs", aggfunc="count"
)
temp_df
# Out:
# ball     1     2     3     4     5     6     7    8    9
# over
# 1      4.0   7.0  17.0  23.0  18.0  18.0  10.0  1.0  NaN
# 2     17.0  17.0  26.0  36.0  30.0  32.0   9.0  4.0  NaN
# 3     44.0  34.0  44.0  38.0  35.0  47.0   5.0  2.0  1.0
# 4     40.0  50.0  39.0  63.0  43.0  43.0   9.0  1.0  NaN
# 5     43.0  47.0  68.0  43.0  49.0  48.0   9.0  2.0  NaN
# 6     51.0  67.0  35.0  47.0  46.0  50.0  10.0  1.0  NaN
# 7     25.0  35.0  21.0  33.0  43.0  22.0   3.0  2.0  NaN
# 8     38.0  40.0  47.0  40.0  46.0  28.0   6.0  NaN  NaN
# 9     57.0  45.0  41.0  46.0  45.0  31.0  11.0  NaN  1.0
# 10    31.0  30.0  43.0  38.0  36.0  45.0   9.0  1.0  NaN
# 11    50.0  55.0  49.0  41.0  51.0  47.0   8.0  NaN  NaN
# 12    55.0  49.0  61.0  55.0  51.0  40.0   6.0  1.0  NaN
# 13    54.0  74.0  47.0  66.0  63.0  55.0   8.0  2.0  NaN
# 14    62.0  64.0  64.0  56.0  52.0  58.0   4.0  2.0  NaN
# 15    52.0  77.0  68.0  66.0  54.0  65.0   7.0  1.0  NaN
# ...

# %%
temp_df.to_html("../datasets/sixes.html")

# %% [markdown]
# # **Export to JSON**

# %%
# lets create a json as batsman name, there team name and runs made

temp_df = df.groupby(["batting_team", "batsman"])["total_runs"].sum().unstack()

temp_df
# Out:
# batsman                      A Ashish Reddy  A Chandila  A Chopra  \
# batting_team
# Chennai Super Kings                     NaN         NaN       NaN
# Deccan Chargers                        40.0         NaN       NaN
# Delhi Daredevils                        NaN         NaN       NaN
# Gujarat Lions                           NaN         NaN       NaN
# Kings XI Punjab                         NaN         NaN       NaN
# Kochi Tuskers Kerala                    NaN         NaN       NaN
# Kolkata Knight Riders                   NaN         NaN      58.0
# Mumbai Indians                          NaN         NaN       NaN
# Pune Warriors                           NaN         NaN       NaN
# Rajasthan Royals                        NaN         4.0       NaN
# Rising Pune Supergiant                  NaN         NaN       NaN
# Rising Pune Supergiants                 NaN         NaN       NaN
# Royal Challengers Bangalore             NaN         NaN       NaN
# ...

# %%
temp_df.to_json("../datasets/ipl_runs.json")

# %% [markdown]
# # **Export to SQL**

# %% [markdown]
# For understanding use Xaammp for demonstration purpose
#
# 1. We will be needing an existing database
# 2. Then we can store that data to the database
# 3. import `pymysql`
# 4. from sql_alchemy import create_engine
#    - This helps you to work with mysql database

# %%
# import pymysql
# from sqlalchemy import create_engine


"""first we need to create an engine"""

# engine = create_engine("mysql+pymysql://username:password@url_can_be_localhost/db_name") #this is the url

# Now after this we will send
# df.to_sql('table_name', con=engine(that is connection object), if_exist='append')

# we can add multiple tables to a single database
# Out:
# 'first we need to create an engine'
